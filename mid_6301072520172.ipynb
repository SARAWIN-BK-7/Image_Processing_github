# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
original_img = plt.imread('medicine_with_noise_mid.jpg')
print("Print Shape image:",original_img.shape)
print("Print dimentaional:",original_img.ndim)
# Out:
# Print Shape image: (1013, 1348, 3)
# Print dimentaional: 3

# %%
plt.imshow(original_img)

# %%
lum_img = original_img[:, :, 0]

plt.imshow(lum_img)

# %%
imgplot = plt.imshow(original_img, interpolation="bicubic")
